# %% [markdown]
# # NYC taxis data analysis

# %%
import numpy as np

# %% [markdown]
# ## Load the data from csv.
# We are going to analyse the data with only numpy so we can't have string data so skiping the header.

# %%
data = np.genfromtxt("nyc_taxis_dataset.csv", delimiter=",", skip_header=True)

# %% [markdown]
# ## Inspecting the Data

# %%
data.shape
# Out:
# (89560, 15)

# %% [markdown]
# It have total 89560 rows and 15 columns

# %%
data.dtype
# Out:
# dtype('float64')

# %% [markdown]
# The all data is numeric.

# %%
data[0]
# Out:
# array([2.016e+03, 1.000e+00, 1.000e+00, 5.000e+00, 0.000e+00, 2.000e+00,
#        4.000e+00, 2.100e+01, 2.037e+03, 5.200e+01, 8.000e-01, 5.540e+00,
#        1.165e+01, 6.999e+01, 1.000e+00])

# %% [markdown]
# column 0 -> pickup_year
# column 1 -> pickup_month
# column 2 -> pickup_day
# column 3 -> pickup_day_of_week
# column 4 -> pickup_time
# column 5 -> pickup_location_code
# column 6 -> dropoff_location_code
# column 7 -> trip_distance
# column 8 -> trip_length
# column 9 -> fare_amount
# column 10 -> fees_amount
# column 11 -> tolls_amount
# column 12 -> tip_amount
# column 13 -> total_amount
# column 14 -> payment_type

# %%
pickup_year = 0
pickup_month = 1
pickup_day = 2
pickup_dayofweek = 3
pickup_time = 4
pickup_location_code = 5
dropoff_location_code = 6
trip_distance = 7
trip_length = 8
fare_amount = 9
fees_amount = 10
tolls_amount = 11
tip_amount = 12
total_amount = 13 
payment_type = 14

# %% [markdown]
# ## Data Cleaning

# %%
np.sum(data[:, trip_distance] <= 0)
# Out:
# np.int64(601)
